# %% [markdown]
# <a href="https://colab.research.google.com/github/tulasigarlankala873/tulasigarlankala873/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 10:16:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   279MB/s    in 0.2s
#
# 2024-03-31 10:16:42 (279 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11580  1606.05642v2  Surprise describes a range of phenomena from u...  stat
# 15749  1603.06067v3  We present a novel method for jointly learning...    cs
# 35518   0806.4802v1  We present a new online learning algorithm for...    cs
# 16435  1702.05793v1  This work presents a systematic theoretical an...    cs
# 7179   1710.10866v1  Approximate dynamic programming algorithms, su...  stat
# ...             ...                                                ...   ...
# 22367  1603.07738v1  Multiplayer Online Battle Arena (MOBA) games a...  stat
# 11477  1603.01901v1  Multi-instance data, in which each object (bag...    cs
# 3606   1802.05451v1  Structured prediction is concerned with predic...  stat
# 26589  1611.04076v3  Unsupervised learning with generative adversar...    cs
# 17630  1801.01999v1  The ability to learn optimal control policies ...    cs
#
#                                                    title  year  \
# 11580  Balancing New Against Old Information: The Rol...  2016
# 15749  Adaptive Joint Learning of Compositional and N...  2016
# 35518  A new Hedging algorithm and its application to...  2008
# 16435  Harmonic Grammar, Optimality Theory, and Synta...  2017
# 7179   Unifying Value Iteration, Advantage Learning, ...  2017
# ...                                                  ...   ...
# 22367  Skill-Based Differences in Spatio-Temporal Tea...  2016
# 11477  Confidence-Constrained Maximum Entropy Framewo...  2016
# 3606   Mapping Images to Scene Graphs with Permutatio...  2018
# 26589      Least Squares Generative Adversarial Networks  2016
# 17630  Using reinforcement learning to learn how to p...  2018
#
#                                                 keywords
# 11580  [describes, phenomena, unexpected, behavioral,...
# 15749  [compositional, compositional, embeddings, ada...
# 35518  [algorithm, cumulative, discounted, algorithm,...
# 16435  [systematic, theoretical, empirical, compariso...
# 7179   [approximate, programming, algorithms, approxi...
# ...                                                  ...
# 22367  [multiplayer, environments, mastering, extensi...
# 11477  [collection, instances, widespread, bioinforma...
# 3606   [structured, prediction, concerned, predicting...
# 26589  [unsupervised, generative, adversarial, succes...
# 17630  [sentences, interesting, applications, automat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11580    [describes, phenomena, unexpected, behavioral,...
# 15749    [compositional, compositional, embeddings, ada...
# 35518    [algorithm, cumulative, discounted, algorithm,...
# 16435    [systematic, theoretical, empirical, compariso...
# 7179     [approximate, programming, algorithms, approxi...
#                                ...
# 14915    [experimental, automatic, objective, linguisti...
# 16249    [prevalent, translation, directional, architec...
# 39065    [orthogonal, multifilters, astronomical, proce...
# 7315     [selection, facilitate, variables, crowdsourci...
# 11925    [reinforcement, considered, interaction, envir...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8882 words.
# Out of those 4635 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="deea1cd1-6f64-4080-8bf7-977dbce54dcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("deea1cd1-6f64-4080-8bf7-977dbce54dcf")) {                    Plotly.newPlot(                        "deea1cd1-6f64-4080-8bf7-977dbce54dcf",                        [{"x":["commitment","eventually","describes","distribution","framework","minimizing","exploration","knowledge","statistics","responses","surprising","behavioral","phenomena","balancing","dynamically","likelihood","unexpected","environment","encountering","information","environments","undergoes","parameters","optimized","disambiguation","technique","substantially","compositional","compositionality","correlation","adaptively","objective","weighting","outperforming","transitive","embeddings","experiments","averaging","variables","alternative","discounted","application","exponential","algorithm","cumulative","particular","inferring","predicting","performance","perceptron","learnability","theoretically","algorithms","appealing","experimental","prediction","approaches","empirical","variation","frameworks","accurately","theoretical","comparison","optimality","sentences","expressivity","systematic","additional","comparing","themselves","guarantee","generalized","numerical","applicability","iteration","programming","arguments","reinforcement","approximated","advantages","guarantees","weaknesses","successfully","approximate","promising","advantage","development","evaluation","earthquake","forecasting","questions","potential","considerable","important","artificial","magnitude","according","preliminary","earthquakes","infrastructure","geological","registered","published","probability","selecting","additionally","obtaining","motivation","consuming","comparisons","intelligently","asymptotic","asymptotically","analyzing","underlying","objectives","efficient","surveillance","applications","interactive","informatics","acquisition","healthcare","classification","detection","visualization","representation","particularly","parametric","interested","retrieval","computation","constraining","impossible","expectations","detectors","significant","opportunity","relabeled","locations","contextual","independently","detecting","containing","correctly","confidence","surrounding","augmented","generally","classifiers","separately","facilitate","improvement","traditional","motivated","understanding","introductory","answering","components","including","expensive","conversation","collection","collected","attention","interactively","extraction","regression","unbounded","frequentist","maximizes","minimization","generated","classical","assumption","inference","explanation","generalization","intrinsic","synthesizer","specially","processing","presented","differentiation","determination","simulator","increasing","determined","photographed","techniques","measurement","synthetic","commercial","comparative","improving","investigate","monitoring","deformation","investigated","comprehensive"],"y":[3,16,89,211,556,45,64,349,76,28,19,16,27,11,28,60,6,108,0,656,81,3,245,54,13,221,54,26,9,76,21,158,24,21,5,72,587,24,151,114,6,254,51,806,12,289,18,77,853,15,4,35,587,15,370,204,392,158,68,26,68,165,129,22,76,5,40,107,77,26,41,83,90,45,36,107,14,105,14,81,66,14,88,123,110,99,130,257,4,21,68,166,36,348,140,67,111,60,2,14,3,3,42,164,35,57,35,25,36,32,4,15,7,56,119,28,413,38,431,38,5,28,9,491,375,35,354,72,38,22,104,140,6,25,9,51,232,9,2,50,52,37,83,50,24,42,13,42,72,113,21,50,139,154,50,151,5,57,110,267,73,16,70,78,166,8,143,101,9,0,12,75,169,108,63,210,31,98,45,3,13,296,170,3,16,13,108,36,3,375,37,127,16,25,88,168,41,14,47,66],"type":"bar"},{"x":["commitment","eventually","describes","distribution","framework","minimizing","exp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4635,), (4635, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Video</span> <span style=''>Super</span> <span style='background-color:rgba(0, 255, 0, 0.5972222222222222);'>Resolution</span> <span style=''>Based</span> <span style=''>On</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequential</span> <span style=''>Model</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>for</span> <span style=''>video</span> <span style=''>super</span> <span style='background-color:rgba(0, 255, 0, 0.5972222222222222);'>resolution</span> <span style=''>that</span> <span style=''>is</span> <span style=''>the</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5972222222222222);'>resolution</span> <span style=''>images</span> <span style=''>from</span> <span style=''>its</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.5972222222222222);'>resolution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>counterpart</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>model</span> <span style=''>(ie</span> <span style=''>each</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5972222222222222);'>resolution</span> <span style=''>frame</span> <span style=''>is</span> <span style=''>supposed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>displaced</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preceding</span> <span style=''>one)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>sparsity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enforcing</span> <span style=''>priors</span> <span style=''>Both</span> <span style=''>the</span> <span style=''>recovery</span> <span style=''>of</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5972222222222222);'>resolution</span> <span style=''>images</span> <span style=''>and</span> <span style=''>the</span> <span style=''>motion</span> <span style=''>fields</span> <span style=''>relating</span> <span style=''>them</span> <span style=''>is</span> <span style=''>tackled</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3383177570093458);'>dimensional</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>fast</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Unsupervised</span> <span style=''>Real</span> <span style=''>Time</span> <span style=''>Control</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Empowerment</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>to</span> <span style=''>empowerment</span> <span style=''>allowing</span> <span style=''>it</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>for</span> <span style=''>policy</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>real</span> <span style=''>time</span> <span style=''>control</span> <span style=''>Empowerment</span> <span style=''>being</span> <span style=''>the</span> <span style=''>channel</span> <span style=''>capacity</span> <span style=''>between</span> <span style=''>actions</span> <span style=''>and</span> <span style=''>states</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximises</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>of</span> <span style=''>an</span> <span style=''>agent</span> <span style=''>on</span> <span style=''>its</span> <span style=''>near</span> <span style=''>future</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>good</span> <span style=''>model</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biological</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behaviour</span> <span style=''>in</span> <span style=''>the</span> <span style=''>absence</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extrinsic</span> <span style=''>goal</span> <span style=''>But</span> <span style=''>empowerment</span> <span style=''>is</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibitively</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>spaces</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>amortised</span> <span style=''>method</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>empowerment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximising</span> <span style=''>policies</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>reliably</span> <span style=''>handle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style=''>Singular</span> <span style=''>Value</span> <span style='background-color:rgba(255, 0, 0, 0.4999999999999999);'>Thresholding</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>studies</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style=''>Singular</span> <span style=''>Value</span> <span style='background-color:rgba(255, 0, 0, 0.4999999999999999);'>Thresholding</span> <span style=''>(GSVT)</span> <span style=''>operator</span> <span style=''>Prox</span> <span style=''>gbmsigma(cdot)</span> <span style=''>beginequation</span> <span style=''>Prox</span> <span style=''>gbmsigma(B)argminlimits</span> <span style=''>Xsum</span> <span style=''>i1mg(sigma</span> <span style=''>i(X))</span> <span style=''>frac12||X</span> <span style=''>B||</span> <span style=''>F2</span> <span style=''>endequation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.375);'>nonconvex</span> <span style=''>function</span> <span style=''>g</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>the</span> <span style=''>singular</span> <span style=''>values</span> <span style=''>of</span> <span style=''>X</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>GSVT</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>the</span> <span style=''>proximal</span> <span style=''>operator</span> <span style=''>of</span> <span style=''>g</span> <span style=''>(denoted</span> <span style=''>as</span> <span style=''>Prox</span> <span style=''>g(cdot))</span> <span style=''>on</span> <span style=''>the</span> <span style=''>singular</span> <span style=''>values</span> <span style=''>since</span> <span style=''>Prox</span> <span style=''>g(cdot)</span> <span style=''>is</span> <span style=''>monotone</span> <span style=''>when</span> <span style=''>g</span> <span style=''>is</span> <span style=''>lower</span> <span style=''>bounded</span> <span style=''>If</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.375);'>nonconvex</span> <span style=''>g</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfies</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>(many</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.375);'>nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>eg</span> <span style=''>ell</span> <span style=''>p</span> <span style=''>norm</span> <span style=''>0p1</span> <span style=''>of</span> <span style=''>ell</span> <span style=''>0</span> <span style=''>norm</span> <span style=''>are</span> <span style=''>special</span> <span style=''>cases)</span> <span style=''>a</span> <span style=''>general</span> <span style=''>solver</span> <span style=''>to</span> <span style=''>find</span> <span style=''>Prox</span> <span style=''>g(b)</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>for</span> <span style=''>any</span> <span style=''>bgeq0</span> <span style=''>GSVT</span> <span style=''>greatly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizes</span> <span style=''>the</span> <span style=''>known</span> <span style=''>Singular</span> <span style=''>Value</span> <span style='background-color:rgba(255, 0, 0, 0.4999999999999999);'>Thresholding</span> <span style=''>(SVT)</span> <span style=''>which</span> <span style=''>is</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>NetGAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generating</span> <span style=''>Graphs</span> <span style=''>via</span> <span style=''>Random</span> <span style=''>Walks</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>NetGAN</span> <span style=''>the</span> <span style=''>first</span> <span style=''>implicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>for</span> <span style=''>graphs</span> <span style=''>able</span> <span style=''>to</span> <span style=''>mimic</span> <span style=''>real</span> <span style=''>world</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>pose</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>as</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>biased</span> <span style=''>random</span> <span style=''>walks</span> <span style=''>over</span> <span style=''>the</span> <span style=''>input</span> <span style=''>graph</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>discrete</span> <span style=''>output</span> <span style=''>samples</span> <span style=''>and</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Wasserstein</span> <span style=''>GAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>NetGAN</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>graphs</span> <span style=''>that</span> <span style=''>exhibit</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>network</span> <span style=''>patterns</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifying</span> <span style=''>them</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>At</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>our</span> <span style=''>model</span> <span style=''>exhibits</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>highlighted</span> <span style=''>by</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>despite</span> <span style=''>not</span> <span style=''>being</span> <span style=''>trained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <span style=''>Being</span> <span style=''>the</span> <span style=''>first</span> <span style=''>approach</span> <span style=''>to</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13139204545454544)
# 	knowledge (0.12393465909090909)
# 	reasoning (0.05078125)
# 	challenging (0.10227272727272728)
# 	processing (0.10511363636363637)
# 	segmentation (0.07066761363636363)
# 	different (0.2567471590909091)
# 	detection (0.13316761363636365)
# 	convolutional (0.13600852272727273)
# 	recognition (0.15305397727272727)
#
# Some Statistics words are:
# 	variables (0.14465725806451613)
# 	theoretical (0.15120967741935484)
# 	statistical (0.1532258064516129)
# 	stochastic (0.14012096774193547)
# 	algorithm (0.3855846774193548)
# 	estimation (0.17641129032258066)
# 	distribution (0.18800403225806453)
# 	dimensional (0.18044354838709678)
# 	inference (0.19959677419354838)
# 	regression (0.17893145161290322)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="01214a4b-48d1-4f85-9439-f50e4fefae2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01214a4b-48d1-4f85-9439-f50e4fefae2f")) {                    Plotly.newPlot(                        "01214a4b-48d1-4f85-9439-f50e4fefae2f",                        [{"x":["commitment","eventually","describes","distribution","framework","minimizing","exploration","knowledge","statistics","responses","surprising","behavioral","phenomena","balancing","dynamically","likelihood","unexpected","environment","encountering","information","environments","undergoes","parameters","optimized","disambiguation","technique","substantially","compositional","compositionality","correlation","adaptively","objective","weighting","outperforming","transitive","embeddings","experiments","averaging","variables","alternative","discounted","application","exponential","algorithm","cumulative","particular","inferring","predicting","performance","perceptron","learnability","theoretically","algorithms","appealing","experimental","prediction","approaches","empirical","variation","frameworks","accurately","theoretical","comparison","optimality","sentences","expressivity","systematic","additional","comparing","themselves","guarantee","generalized","numerical","applicability","iteration","programming","arguments","reinforcement","approximated","advantages","guarantees","weaknesses","successfully","approximate","promising","advantage","development","evaluation","earthquake","forecasting","questions","potential","considerable","important","artificial","magnitude","according","preliminary","earthquakes","infrastructure","geological","registered","published","probability","selecting","additionally","obtaining","motivation","consuming","comparisons","intelligently","asymptotic","asymptotically","analyzing","underlying","objectives","efficient","surveillance","applications","interactive","informatics","acquisition","healthcare","classification","detection","visualization","representation","particularly","parametric","interested","retrieval","computation","constraining","impossible","expectations","detectors","significant","opportunity","relabeled","locations","contextual","independently","detecting","containing","correctly","confidence","surrounding","augmented","generally","classifiers","separately","facilitate","improvement","traditional","motivated","understanding","introductory","answering","components","including","expensive","conversation","collection","collected","attention","interactively","extraction","regression","unbounded","frequentist","maximizes","minimization","generated","classical","assumption","inference","explanation","generalization","intrinsic","synthesizer","specially","processing","presented","differentiation","determination","simulator","increasing","determined","photographed","techniques","measurement","synthetic","commercial","comparative","improving","investigate","monitoring","deformation","investigated","comprehensive","achieving","reconstruction","developed","reconstruct","displacement","engineering","obtrusive","literature","significantly","photogrammetric","solutions","properties","evidential","discussed","intervals","operations","identifiers","appropriate","determining","combining","hypothesis","limitations","robustness","combination","associative","constructing","simplifying","reasoning","tradeoffs","reliability","flexibility","increases","exploring","computing","performing","therefore","desirable","influence","evolutionary","optimization","redundancy","increasingly","distributions","differences","different","examining","observable","developing","assessing","emphasize","available","diversity","realistic","experience","cognitive","introduces", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	encountering
# 	frequentist
# 	penalties
# 	corollary
# 	agricultural
# 	underpowered
# 	precautions
# 	gaussianity
# 	nonconjugate
# 	intentionally
# 	forthcoming
# 	predominant
# 	blockwise
# 	physiologic
# 	pediatric
# 	misclassify
# 	integrator
# 	integrators
# 	legitimate
# 	neuroimage
# Some words which never appear in Statistics papers:
# 	disambiguation
# 	earthquake
# 	earthquakes
# 	relabeled
# 	introductory
# 	synthesizer
# 	photographed
# 	obtrusive
# 	photogrammetric
# 	evidential
# 	identifiers
# 	grounding
# 	proactive
# 	workstation
# 	strategically
# 	densenets
# 	propositions
# 	transitioning
# 	composing
# 	starcraft

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0492453117853333e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
